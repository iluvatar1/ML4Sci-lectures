# %% [markdown]
# # Principal Component Analysis (PCA)

# %%
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# #### Descargar los datos

# %%
datos=np.genfromtxt("WDBC.dat",  delimiter=",")
#print(datos[0:4,:])

# %%
promedio=np.mean(datos[:,1])
for i in range (np.shape(datos)[1]):
    datos[:,i]=(datos[:,i]-np.mean(datos[:,i]))/np.std(datos[:,i])

# %%
covmat=np.cov(datos[:,1:].T)

# %%
valores, vectores= np.linalg.eig(covmat)
valores=valores/np.sum(valores)
#print(valores)

# %%
plt.figure()
plt.scatter(np.arange(len(valores)),valores)
plt.plot(np.arange(len(valores)),valores)

# %%
per_var=(valores[0]+valores[1]+valores[2])
print(per_var)
# Out:
# 0.7255152452459432

# %%
print( "autovectores 1: ",vectores[:,0])
print( "autovectores 2: ",vectores[:,1])
datosPC = np.dot(datos[:,1:], vectores)
# Out:
# autovectores 1:  [ 0.21691695 -0.21639914 -0.10359936 -0.2245478  -0.21796464 -0.13764549
#  -0.23150388 -0.25122179 -0.2552664  -0.1330126  -0.05797189 -0.20090409
#  -0.01547414 -0.20563036 -0.19798194 -0.01123624 -0.1619218  -0.14578435
#  -0.1762679  -0.03832541 -0.09508414 -0.22558983 -0.10501867 -0.23364163
#  -0.22196962 -0.12530106 -0.20447639 -0.22307483 -0.24628844 -0.12066328
#  -0.12672101]
# autovectores 2:  [ 0.07760994 -0.22654473 -0.05826196 -0.20762951 -0.22322434  0.18876038
#   0.15847307  0.06786768 -0.02722028  0.19321967  0.36761956 -0.09715581
#   0.09118826 -0.08069084 -0.14355563  0.20531469  0.23886735  0.203226
#   0.13704859  0.1860032   0.28433173 -0.21289639 -0.04513536 -0.19259202
#  -0.21188718  0.17247591  0.14766283  0.10308807 -0.00243309  0.14206245
#   0.27644912]

# %%
plt.figure()
for i in range(1,np.shape(datos)[0]):
    if (datos[i,1]>promedio):
        plt.scatter(datosPC[i,0],datosPC[i,1], c="b", alpha=0.2)
    if (datos[i,1]<promedio):
        plt.scatter(datosPC[i,0],datosPC[i,1], c="r", alpha=0.2)
